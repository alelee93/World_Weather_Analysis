# %%
#import the dependencies

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
#Add the latitudes and longitudes to a list
#remember you can only unzip a zipped tuple once before it is removed from the computers memory.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 605

# %%
# Import the requests library.
import requests

# Import the API key
from config import weather_api_key

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | constitucion
# Processing Record 2 of Set 1 | comodoro rivadavia
# Processing Record 3 of Set 1 | vardo
# Processing Record 4 of Set 1 | rio grande
# Processing Record 5 of Set 1 | manggar
# Processing Record 6 of Set 1 | esperance
# Processing Record 7 of Set 1 | pangody
# Processing Record 8 of Set 1 | olafsvik
# Processing Record 9 of Set 1 | vargem grande
# Processing Record 10 of Set 1 | coracora
# Processing Record 11 of Set 1 | avarua
# Processing Record 12 of Set 1 | atuona
# Processing Record 13 of Set 1 | shimoda
# Processing Record 14 of Set 1 | arraial do cabo
# Processing Record 15 of Set 1 | khatanga
# Processing Record 16 of Set 1 | dickinson
# Processing Record 17 of Set 1 | jijiga
# Processing Record 18 of Set 1 | hithadhoo
# Processing Record 19 of Set 1 | port alfred
# Processing Record 20 of Set 1 | severo-kurilsk
# Processing Record 21 of Set 1 | port lincoln
# Processing Record 22 of Set 1 | kutum
# Processing Record 23 of Set 1 | cape town
# Processing Record 24 of Set 1 | rock sound
# Processing Record 25 of Set 1 | saint-philippe
# Processing Record 26 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 27 of Set 1 | ahuimanu
# Processing Record 28 of Set 1 | nikolskoye
# Processing Record 29 of Set 1 | rikitea
# Processing Record 30 of Set 1 | jamestown
# Processing Record 31 of Set 1 | barrow
# Processing Record 32 of Set 1 | punta arenas
# Processing Record 33 of Set 1 | ushuaia
# Processing Record 34 of Set 1 | albany
# Processing Record 35 of Set 1 | torbay
# Processing Record 36 of Set 1 | grand gaube
# Processing Record 37 of Set 1 | maragogi
# Processing Record 38 of Set 1 | ahwa
# Processing Record 39 of Set 1 | kurumkan
# Processing Record 40 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 41 of Set 1 | puerto ayora
# Processing Record 42 of Set 1 | altay
# Processing Record 43 of Set 1 | scottsbluff
# Processing Record 44 of Set 1 | butaritari
# Processing Record 45 of Set 1 | arrecife
# Processing Record 46 of Set 1 | upernavik
# Processing Record 47 of Set 1 | pevek
# Processing Record 48 of Set 1 | tolyatti
# Processing Record 49 of Set 1 | klaksvik
# Processing Record 50 of Set 1 | macheng
# Processing Record 1 of Set 2 | dikson
# Processing Record 2 of Set 2 | azogues
# Processing Record 3 of Set 2 | remedios
# Processing Record 4 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 5 of Set 2 | te anau
# Processing Record 6 of Set 2 | marsa matruh
# Processing Record 7 of Set 2 | fortuna
# Processing Record 8 of Set 2 | ixtapa
# Processing Record 9 of Set 2 | isangel
# Processing Record 10 of Set 2 | busselton
# Processing Record 11 of Set 2 | barillas
# Processing Record 12 of Set 2 | xining
# Processing Record 13 of Set 2 | airai
# Processing Record 14 of Set 2 | shahrud
# Processing Record 15 of Set 2 | victoria
# Processing Record 16 of Set 2 | moose factory
# Processing Record 17 of Set 2 | morwa
# Processing Record 18 of Set 2 | georgetown
# Processing Record 19 of Set 2 | cabo san lucas
# Processing Record 20 of Set 2 | eyl
# Processing Record 21 of Set 2 | kaitangata
# Processing Record 22 of Set 2 | ostrovnoy
# Processing Record 23 of Set 2 | shar
# Processing Record 24 of Set 2 | vacaria
# Processing Record 25 of Set 2 | veraval
# Processing Record 26 of Set 2 | mar del plata
# Processing Record 27 of Set 2 | bani walid
# Processing Record 28 of Set 2 | port-gentil
# Processing Record 29 of Set 2 | inhambane
# Processing Record 30 of Set 2 | macusani
# Processing Record 31 of Set 2 | carnarvon
# Processing Record 32 of Set 2 | beaverlodge
# Processing Record 33 of Set 2 | chibombo
# Processing Record 34 of Set 2 | alofi
# Processing Record 35 of Set 2 | tongchuan
# Processing Record 36 of Set 2 | saskylakh
# Processing Record 37 of Set 2 | bluff
# Processing Record 38 of Set 2 | sakaiminato
# Processing Record 39 of Set 2 | barwaha
# City not found. Skipping...
# Processing Record 40 of Set 2 | elesbao veloso
# Processing Record 41 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 42 of Set 2 | yellowknife
# Processing Record 43 of Set 2 | linxia
# Processing Record 44 of Set 2 | norman wells
# Processing Record 45 of Set 2 | nanortalik
# Processing Record 46 of Set 2 | kodiak
# Processing Record 47 of Set 2 | yeppoon
# Processing Record 48 of Set 2 | seminole
# Processing Record 49 of Set 2 | hobart
# Processing Record 50 of Set 2 | zhigansk

# %%
# Out:
# Processing Record 1 of Set 1 | rikitea
# Processing Record 2 of Set 1 | hobart
# Processing Record 3 of Set 1 | puerto ayora
# Processing Record 4 of Set 1 | avarua
# Processing Record 5 of Set 1 | bredy
# Processing Record 6 of Set 1 | barrow
# Processing Record 7 of Set 1 | kamina
# Processing Record 8 of Set 1 | khatanga
# Processing Record 9 of Set 1 | bengkulu
# Processing Record 10 of Set 1 | airai
# Processing Record 11 of Set 1 | lompoc
# Processing Record 12 of Set 1 | kalmunai
# Processing Record 13 of Set 1 | dingle
# Processing Record 14 of Set 1 | viedma
# Processing Record 15 of Set 1 | isangel
# Processing Record 16 of Set 1 | ulladulla
# Processing Record 17 of Set 1 | yellowknife
# Processing Record 18 of Set 1 | mirik
# Processing Record 19 of Set 1 | coquimbo
# Processing Record 20 of Set 1 | caravelas
# Processing Record 21 of Set 1 | ponta delgada
# Processing Record 22 of Set 1 | flinders
# Processing Record 23 of Set 1 | ewa beach
# Processing Record 24 of Set 1 | ponta do sol
# Processing Record 25 of Set 1 | mataura
# Processing Record 26 of Set 1 | diego de almagro
# Processing Record 27 of Set 1 | provideniya
# Processing Record 28 of Set 1 | new norfolk
# Processing Record 29 of Set 1 | mayo
# Processing Record 30 of Set 1 | punta arenas
# Processing Record 31 of Set 1 | sentyabrskiy
# Processing Record 32 of Set 1 | paamiut
# Processing Record 33 of Set 1 | ushuaia
# Processing Record 34 of Set 1 | te anau
# Processing Record 35 of Set 1 | arraial do cabo
# Processing Record 36 of Set 1 | chatellerault
# Processing Record 37 of Set 1 | chuy
# Processing Record 38 of Set 1 | bakchar
# Processing Record 39 of Set 1 | albany
# Processing Record 40 of Set 1 | illoqqortoormiut
# Processing Record 41 of Set 1 | saskylakh
# Processing Record 42 of Set 1 | sitka
# Processing Record 43 of Set 1 | muros
# Processing Record 44 of Set 1 | chokurdakh
# Processing Record 45 of Set 1 | taolanaro
# Processing Record 46 of Set 1 | hilo
# Processing Record 47 of Set 1 | port alfred
# Processing Record 48 of Set 1 | port elizabeth
# Processing Record 49 of Set 1 | tazovskiy
# Processing Record 50 of Set 1 | bathsheba
# Processing Record 1 of Set 2 | paralimni
# Processing Record 2 of Set 2 | yeppoon
# Processing Record 3 of Set 2 | lebu
# Processing Record 4 of Set 2 | conakry
# Processing Record 5 of Set 2 | champerico
# Processing Record 6 of Set 2 | maykain
# Processing Record 7 of Set 2 | zlitan
# Processing Record 8 of Set 2 | saint-philippe
# Processing Record 9 of Set 2 | busselton
# Processing Record 10 of Set 2 | laguna
# Processing Record 11 of Set 2 | quatre cocos
# Processing Record 12 of Set 2 | belushya guba
# Processing Record 13 of Set 2 | kavieng
# Processing Record 14 of Set 2 | clyde river
# Processing Record 15 of Set 2 | luderitz
# Processing Record 16 of Set 2 | karatuzskoye
# Processing Record 17 of Set 2 | novikovo
# Processing Record 18 of Set 2 | huarmey
# Processing Record 19 of Set 2 | simao
# Processing Record 20 of Set 2 | nadym
# Processing Record 21 of Set 2 | ribeira grande
# Processing Record 22 of Set 2 | liverpool
# Processing Record 23 of Set 2 | alice springs
# Processing Record 24 of Set 2 | kisanga
# Processing Record 25 of Set 2 | langxiang
# Processing Record 26 of Set 2 | atuona
# Processing Record 27 of Set 2 | jamestown
# Processing Record 28 of Set 2 | leningradskiy
# Processing Record 29 of Set 2 | victoria
# Processing Record 30 of Set 2 | severo-kurilsk
# Processing Record 31 of Set 2 | san patricio
# Processing Record 32 of Set 2 | beringovskiy
# Processing Record 33 of Set 2 | elverum
# Processing Record 34 of Set 2 | mahanje
# Processing Record 35 of Set 2 | abilene
# Processing Record 36 of Set 2 | saldanha
# Processing Record 37 of Set 2 | samusu
# Processing Record 38 of Set 2 | tuktoyaktuk
# Processing Record 39 of Set 2 | tondano
# Processing Record 40 of Set 2 | merauke
# Processing Record 41 of Set 2 | geraldton
# Processing Record 42 of Set 2 | esperance
# Processing Record 43 of Set 2 | myitkyina
# Processing Record 44 of Set 2 | amapa
# Processing Record 45 of Set 2 | ksenyevka
# Processing Record 46 of Set 2 | srednekolymsk
# Processing Record 47 of Set 2 | butaritari
# Processing Record 48 of Set 2 | westlock
# Processing Record 49 of Set 2 | ishigaki
# Processing Record 50 of Set 2 | barentsburg
# Processing Record 1 of Set 3 | halifax
# Processing Record 2 of Set 3 | tiksi
# Processing Record 3 of Set 3 | marawi
# Processing Record 4 of Set 3 | helong
# Processing Record 5 of Set 3 | itaituba
# Processing Record 6 of Set 3 | panji
# Processing Record 7 of Set 3 | karabulak
# Processing Record 8 of Set 3 | nikolskoye
# Processing Record 9 of Set 3 | east london
# Processing Record 10 of Set 3 | galgani
# Processing Record 11 of Set 3 | vao
# Processing Record 12 of Set 3 | bolshaya irba
# Processing Record 13 of Set 3 | georgetown
# Processing Record 14 of Set 3 | jumla
# Processing Record 15 of Set 3 | qaanaaq
# Processing Record 16 of Set 3 | sandwick
# Processing Record 17 of Set 3 | castro
# Processing Record 18 of Set 3 | rio grande
# Processing Record 19 of Set 3 | tasiilaq
# Processing Record 20 of Set 3 | moron
# Processing Record 21 of Set 3 | kamenskoye
# Processing Record 22 of Set 3 | vaini
# Processing Record 23 of Set 3 | ancud
# Processing Record 24 of Set 3 | bluff
# Processing Record 25 of Set 3 | dudinka
# Processing Record 26 of Set 3 | mount isa
# Processing Record 27 of Set 3 | san felipe
# Processing Record 28 of Set 3 | acuna
# Processing Record 29 of Set 3 | cape town
# Processing Record 30 of Set 3 | pangnirtung
# Processing Record 31 of Set 3 | khatra
# Processing Record 32 of Set 3 | tuatapere
# Processing Record 33 of Set 3 | longyearbyen
# Processing Record 34 of Set 3 | la ronge
# Processing Record 35 of Set 3 | bedford
# Processing Record 36 of Set 3 | saint anthony
# Processing Record 37 of Set 3 | broome
# Processing Record 38 of Set 3 | yaguajay
# Processing Record 39 of Set 3 | burica
# Processing Record 40 of Set 3 | brae
# Processing Record 41 of Set 3 | narsaq
# Processing Record 42 of Set 3 | ilulissat
# Processing Record 43 of Set 3 | carnarvon
# Processing Record 44 of Set 3 | peleduy
# Processing Record 45 of Set 3 | kaitangata
# Processing Record 46 of Set 3 | agnibilekrou
# Processing Record 47 of Set 3 | grude
# Processing Record 48 of Set 3 | aumbay
# Processing Record 49 of Set 3 | richards bay
# Processing Record 50 of Set 3 | mendi
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/bb/8gl1y7m17k78zwr5fblypj6m0000gn/T/ipykernel_29712/325064266.py in <module>
#       6         set_count += 1
#       7         record_count = 1
# ----> 8         time.sleep(60)
#       9
#      10     # Create endpoint URL with each city.
#
# KeyboardInterrupt:

# %%
# Out:
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Out:
# [{'City': 'Upernavik',
#   'Lat': -6.1761,
#   'Lng': 143.6513,
#   'Max Temp': 58.95,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 1.32,
#   'Country': 'PG',
#   'Date': '2022-03-02 06:00:25'},
#  {'City': 'Upernavik',
#   'Lat': -6.1761,
#   'Lng': 143.6513,
#   'Max Temp': 58.95,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 1.32,
#   'Country': 'PG',
#   'Date': '2022-03-02 06:00:25'}]
